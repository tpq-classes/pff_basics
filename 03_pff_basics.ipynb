# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>

# %% [markdown]
# # Python for Finance Basics

# %% [markdown]
# &copy; Dr. Yves J. Hilpisch | The Python Quants GmbH
#
# http://tpq.io | [training@tpq.io](mailto:trainin@tpq.io) | [@dyjh](http://twitter.com/dyjh)

# %% [markdown]
# ## Data Structures

# %% [markdown]
# ## `tuple` objects

# %% [markdown]
# `tuple` objects are **immutable**.

# %%
# !git clone https://github.com/tpq-classes/pff_basics.git
import sys
sys.path.append('pff_basics')

# %%
1, 2, 3, 4

# %%
t = 1, 2, 3, 4

# %%
t

# %%
type(t)

# %%
t.count(3)

# %%
t.index(3)

# %%
t[0]

# %%
t[1]

# %%
t[-1]

# %%
t[:2]

# %%
t[2:]

# %%
t = 1, 2.5, 3, 4.75

# %%
t

# %%
t = (1, 2.5, 3, 4.75)

# %%
t

# %%
t = (1, 2.5, 'python', True)

# %%
t

# %%
t + t

# %%
2 * t

# %%
# range?

# %%
range(0, 15, 2)

# %%
tuple(range(0, 15, 2))

# %% [markdown]
# ## `list` objects

# %% [markdown]
# `list` objects are **mutable**.

# %%
l = [1, 2, 3, 4]

# %%
l

# %%
type(l)

# %%
l.count(3)

# %%
l.index(3)

# %%
l.append(6)

# %%
l

# %%
l.remove(4)

# %%
l

# %%
l.insert(3, 5)

# %%
l

# %%
l[0]

# %%
l[2]

# %%
l[-1]

# %%
l[:2]

# %%
l = [1, 2.5, 'jupyter', False]

# %%
l

# %%
l[0]

# %%
l[0] = 2

# %%
l

# %%
l[-1] = True

# %%
l

# %%
t

# %%
l.append(t)

# %%
l

# %%
l + l

# %%
2 * l

# %%
# range?

# %%
range(10)

# %%
list(range(10))

# %%
list(range(3, 20))

# %%
list(range(5, 26, 4))

# %%
l = list(range(25))

# %%
l[:6]

# %%
sum(l)

# %%
min(l)

# %%
max(l)

# %%
len(l)

# %%
mean = sum(l) / len(l)

# %%
mean

# %%
def f(x):
    ''' Return the square of x. '''
    return x ** 2

# %%
f(2)

# %%
f(16.5)

# %%
def mean(x):
    ''' Calculate the mean of all elements of x. '''
    return sum(x) / len(x)

# %%
mean(l)

# %%
t = tuple(range(4, 120, 7))
t

# %%
mean(t)

# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="mailto:training@tpq.io">training@tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a>
