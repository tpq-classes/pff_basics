# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>

# %% [markdown]
# # Python for Finance Basics

# %% [markdown]
# &copy; Dr. Yves J. Hilpisch | The Python Quants GmbH
#
# http://tpq.io | [training@tpq.io](mailto:trainin@tpq.io) | [@dyjh](http://twitter.com/dyjh)

# %% [markdown]
# ## `numpy` package

# %%
# !git clone https://github.com/tpq-classes/pff_basics.git
import sys
sys.path.append('pff_basics')

# %%
import numpy as np

# %% [markdown]
# ## Creating `ndarray` objects

# %% [markdown]
# `ndarray` = n-dimensional array (multi-dimensional array)

# %%
l = list(range(10))
l

# %%
a = np.array(l)

# %%
a

# %%
type(a)

# %%
t = tuple(range(10))
t

# %%
a = np.array(t)

# %%
a

# %%
a = np.array(range(10))

# %%
a

# %%
type(a)

# %%
a = np.arange(10)

# %%
a

# %%
a = np.zeros(10)

# %%
a

# %%
a = np.ones(10)

# %%
a

# %%
list()  # empty list object

# %%
a = np.empty(10)  # "unpredictable" behaviour (can be faster)

# %%
a

# %%
list(range(3, 17, 3))

# %%
np.arange(0.1, 5.5, 0.335)

# %%
np.linspace(0, 10, 20)

# %%
np.linspace(0, 10, 21)

# %% [markdown]
# ## `dtypes` of `ndarray` objects

# %% [markdown]
# Regular `ndarray` objects are characterized by having a single `dtype` for all the elements.

# %%
a = np.arange(10)
a

# %%
a.dtype

# %%
a = np.arange(10, dtype=float)
a

# %%
a.dtype

# %%
s = np.array(list('abcdefghil'))
s

# %%
s.dtype

# %% [markdown]
# ## Other attributes

# %%
a

# %%
a.dtype

# %%
a.nbytes

# %%
a.size

# %%
len(a)

# %%
a.ndim

# %%
a.shape

# %% [markdown]
# ## Selected methods

# %%
a.astype(int)

# %%
a.tolist()

# %%
list(a)

# %%
a.sum()

# %%
sum(a)

# %%
b = np.arange(1000000)

# %%
# %timeit b.sum()

# %%
# %timeit sum(b)

# %%
# %timeit b.tolist()

# %%
# %timeit list(b)

# %%
a.min()

# %%
a.max()

# %%
a.mean()

# %%
# %time a.std()

# %%
# %time b.std()

# %%
a

# %%
a.cumsum()

# %%
a.cumprod()

# %%
c = np.linspace(1, 10, 7)
c

# %%
np.set_printoptions(suppress=True)

# %%
c.cumprod()

# %%
2 * l  # two times the list object

# %%
a.repeat(2)

# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="mailto:training@tpq.io">training@tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a>
